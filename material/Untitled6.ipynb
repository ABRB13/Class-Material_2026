# %%
class Car:
    
    wheels = 4 #attribute 
    
    def __init__(self, brand, model, year): #construtor method
        self.brand = brand
        self.model = model
        self.year = year
# Out:
#   Cell In[2], line 8
#
#     ^
# SyntaxError: incomplete input

# %%
Car
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Car
#
# NameError: name 'Car' is not defined
