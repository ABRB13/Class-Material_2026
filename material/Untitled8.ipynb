# %%
#oops: encapsulation, inheritance, polymorphism,super, magic methods, __init__, __str__

# %%
#conditional statements and control flow 

#custom functions 
    #conditional statements and control flow 

#class
    #custom functions 
    #conditional statements and control flow 

#week 1 to week 7


#file operations 
#if elif else 
#for and while loop

# %%
#if elif else 
#for and while loop 

#no questions turtle, or tkinter or, opencv
