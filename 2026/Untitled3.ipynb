# %%
 #ITERATIVE
def walk(steps):
    for step in range(1, steps+1):
        print(f"You take step #{step}")

#RECURSIVE
def walk(steps):
#     if steps == 0:
#         return
    print(f"You take step #{steps}")
    walk(steps - 1)

# %%
walk(10)
# Out:
# You take step #10
# You take step #9
# You take step #8
# You take step #7
# You take step #6
# You take step #5
# You take step #4
# You take step #3
# You take step #2
# You take step #1
# You take step #0
# You take step #-1
# You take step #-2
# You take step #-3
# You take step #-4
# You take step #-5
# You take step #-6
# You take step #-7
# You take step #-8
# You take step #-9
# You take step #-10
# You take step #-11
# You take step #-12
# You take step #-13
# You take step #-14
# You take step #-15
# You take step #-16
# You take step #-17
# You take step #-18
# You take step #-19
# You take step #-20
# You take step #-21
# You take step #-22
# You take step #-23
# You take step #-24
# You take step #-25
# You take step #-26
# You take step #-27
# You take step #-28
# You take step #-29
# You take step #-30
# You take step #-31
# You take step #-32
# You take step #-33
# You take step #-34
# You take step #-35
# You take step #-36
# You take step #-37
# You take step #-38
# ...
