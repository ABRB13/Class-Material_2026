# %%
#functions 

#main()


def add(a,b):
    return a +b

def multiply(a,b):
    return a * b

def main():
    x, y = 10, 5
    
    print(f"Addition: {add(x,y)}")
    print(f"mul: {multiply(x,y)}")

# %%
if __name__ == '__main__':
    main()
# Out:
# Addition: 15
# mul: 50

# %%
print(var)
# Out:
# 7

# %%
#user authenticate 

def user_input():
    return input("username: "), input("password:")

def validate_creds(username, password):
    return username == "admin" and password == "123"

def main():
    user, pwd = user_input()
    if validate_creds(user, pwd):
        print("success")
    else:
        print("wrong")

# %%
if __name__ == '__main__':
    main()
# Out:
# username: sergfs
# password:2345
# wrong

# %%
#exception handling 

try:
    num = int(input("Enter a number: "))
    print(f"You entered: {num}")
except ValueError:
    print("Invalid input! Please enter a valid number.")
# Out:
# Enter a number: dfgdfg
# Invalid input! Please enter a valid number.

# %%
def main():
    scores = {"Alice": 95, "B": 80, "C": 90}
    for name, score in scores.items(): n
        print(f"{name}: {score}%")
    print("all displayed")

if __name__ == '__main__':
    main()
# Out:
# Alice: 95%
# B: 80%
# C: 90%
# all displayed

# %%
from example1 import add

add(2,5)
# Out:
# 7

# %%
import pandas as pd 


df = pd.read_csv('2339-2439.csv')

# %%
df
# Out:
#         CUI                                             RXNORM  \
# 0     93253  hydrochlorothiazide 25 MG / triamterene 37.5 M...
# 1     93253  hydrochlorothiazide 25 MG / triamterene 37.5 M...
# 2     93253  hydroCHLOROthiazide 25 MG / triamterene 37.5 M...
# 3     93253                             Maxzide-25 Oral Tablet
# 4     93253  HCTZ 25 MG / Triamterene 37.5 MG Oral Tablet [...
# ..      ...                                                ...
# 98   100272        Lactobacillus delbrueckii subsp. bulgaricus
# 99   100272                           Lactobacillus bulgaricus
# 100  100278                       Lacticaseibacillus rhamnosus
# 101  100278                      Lactobacillus casei rhamnosus
# 102  101306                                          Herceptin
#
#                                      Ingredient  \
# 0                          hydrochlorothiazide
# 1                                   triamterene
# 2                          hydroCHLOROthiazide
# ...

# %%
df1 = df['RXNORM']

# %%
df1
# Out:
# 0      hydrochlorothiazide 25 MG / triamterene 37.5 M...
# 1      hydrochlorothiazide 25 MG / triamterene 37.5 M...
# 2      hydroCHLOROthiazide 25 MG / triamterene 37.5 M...
# 3                                 Maxzide-25 Oral Tablet
# 4      HCTZ 25 MG / Triamterene 37.5 MG Oral Tablet [...
#                              ...
# 98           Lactobacillus delbrueckii subsp. bulgaricus
# 99                              Lactobacillus bulgaricus
# 100                         Lacticaseibacillus rhamnosus
# 101                        Lactobacillus casei rhamnosus
# 102                                            Herceptin
# Name: RXNORM, Length: 103, dtype: object

# %%
df1[5].title()
# Out:
# 'Hctz 25 Mg / Triamterene 37.5 Mg Oral Tablet [Maxzide]'

# %%
import pandas as pd 

def analyze_text_column(df, column1, column2):
    df['processing'] = df['column1'].split()
    df['proc2'] = df['column2'].len()
    return df 

def main():
    
    df = pd.read_csv('2339-2439.csv')
    output = analyze_text_column(df, RXNORM, Ingredient)
    print(output)

# %%
if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[63], line 11, in main()
#       8 def main():
#      10     df = pd.read_csv('2339-2439.csv')
# ---> 11     output = analyze_text_column(df, RXNORM, Ingredient)
#      12     print(output)
#
# NameError: name 'RXNORM' is not defined
