# %%
print("hello")
# Out:
# hello

# %%
def add(a,b):
    c = a + b #it adds two numbers `
    print(c)

# %%
[]
{}
()

# %%
2 + 5
# Out:
# 7

# %%
print(2/3)
# Out:
# 0.6666666666666666

# %%
width = 9
height = 5

total = width + height 

print(total)
# Out:
# 14

# %%
text1 = "1.13" 
text2 = "dkfjsldkfjdsefkasdhfkas"

# %%
#control-flow statements
#loops (for, while)
#functions
#recursive functions 
#data structures 
#object oriented programming

# %%
#conditional statements 

#if 



#elif 

#elif

#else

# %%
x = 10

if (x > 10):
    print('great')
elif (x == 10):
    print('equal')
else:
    print('small')
# Out:
# equal
